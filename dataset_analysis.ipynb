# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Pfad zum Ordner mit den Bildern
ordner_pfad_train = './dataset/train_images'
ordner_pfad_test = './dataset/test_images'


data = []

for ordner_name in os.listdir(ordner_pfad_train):
    documentcount = 0
    for datei in os.listdir(f"{ordner_pfad_train}/{ordner_name}"):
        documentcount += 1
        
    data.append({"ordner_name": ordner_name,
                 "ordner_typ": "train",
                 "anzahl_objekte": documentcount})
        
for ordner_name in os.listdir(ordner_pfad_test):
    documentcount = 0
    for datei in os.listdir(f"{ordner_pfad_test}/{ordner_name}"):
        documentcount += 1
        
    data.append({"ordner_name": ordner_name,
                 "ordner_typ": "train",
                 "anzahl_objekte": documentcount})

df = pd.DataFrame(data, columns=["ordner_name", "ordner_typ", "anzahl_objekte"])

# %%
# Gruppiere nach 'ordner_name' und summiere die 'anzahl_objekte'
grouped_df = df.groupby('ordner_name')['anzahl_objekte'].sum().reset_index()

# Finde die Datensätze mit den minimalen und maximalen Werten in 'anzahl_objekte'
min_objekte = grouped_df.loc[grouped_df['anzahl_objekte'].idxmin()]
max_objekte = grouped_df.loc[grouped_df['anzahl_objekte'].idxmax()]

print("\nDatensatz mit der minimalen Anzahl an Objekten:")
print(min_objekte)

print("\nDatensatz mit der maximalen Anzahl an Objekten:")
print(max_objekte)
# Out:
# Datensatz mit der minimalen Anzahl an Objekten:
# ordner_name       Jackson_Pollock
# anzahl_objekte                 24
# Name: 25, dtype: object
#
# Datensatz mit der maximalen Anzahl an Objekten:
# ordner_name       Vincent_van_Gogh
# anzahl_objekte                 877
# Name: 48, dtype: object

# %%
grouped_df.sort_values(by="anzahl_objekte")
# Out:
#                   ordner_name  anzahl_objekte
# 25            Jackson_Pollock              24
# 14           Eugene_Delacroix              31
# 17             Georges_Seurat              43
# 34               Paul_Cezanne              47
# 31               Michelangelo              49
# 6                  Caravaggio              55
# 20            Gustave_Courbet              59
# 49             William_Turner              66
# 12               Edvard_Munch              67
# 22             Henri_Rousseau              70
# 8                Diego_Rivera              70
# 7                Claude_Monet              73
# 23  Henri_de_Toulouse-Lautrec              81
# 26               Jan_van_Eyck              81
# 39              Piet_Mondrian              84
# 13                   El_Greco              87
# 47         Vasiliy_Kandinskiy              88
# 11              Edouard_Manet              90
# 5            Camille_Pissarro              91
# 3               Andrei_Rublev              99
# 27                  Joan_Miro             102
# 41                    Raphael             109
# 19               Gustav_Klimt             117
# 18          Giotto_di_Bondone             119
# 16                Frida_Kahlo             120
# 28           Kazimir_Malevich             126
# 9             Diego_Velazquez             128
# 40             Pieter_Bruegel             134
# 24           Hieronymus_Bosch             137
# 44              Salvador_Dali             139
# 37          Peter_Paul_Rubens             141
# 29          Leonardo_da_Vinci             143
# 45          Sandro_Botticelli             164
# 32             Mikhail_Vrubel             171
# 4                 Andy_Warhol             181
# 21              Henri_Matisse             186
# 36                  Paul_Klee             188
# 2           Amedeo_Modigliani             193
# 43              Rene_Magritte             194
# 30               Marc_Chagall             239
# 46                     Titian             255
# 1               Alfred_Sisley             259
# 42                  Rembrandt             262
# 15             Francisco_Goya             291
# 35               Paul_Gauguin             311
# 0             Albrecht_Duerer             328
# 38      Pierre-Auguste_Renoir             336
# 33              Pablo_Picasso             439
# 10                Edgar_Degas             702
# 48           Vincent_van_Gogh             877

# %%
img_paths = ["./dataset/train_images/Albrecht_Duerer/Albrecht_Duerer_1.jpg",
             "./dataset/train_images/Alfred_Sisley/Alfred_Sisley_1.jpg",
             "./dataset/train_images/Amedeo_Modigliani/Amedeo_Modigliani_1.jpg"]

titles = {img_path: os.path.basename(img_path) for img_path in img_paths}

num_images = len(img_paths)

print(titles)

fig, axes = plt.subplots(1, num_images, figsize=(15, 5))

if num_images == 1:
    axes = [axes]
    
for ax, img_path in zip(axes, img_paths):
    image = Image.open(img_path)
    ax.imshow(image)
    if titles:
        ax.set_title(titles[img_path])
    ax.axis('off')

plt.show()
# Out:
# {'./dataset/train_images/Albrecht_Duerer/Albrecht_Duerer_1.jpg': 'Albrecht_Duerer_1.jpg', './dataset/train_images/Alfred_Sisley/Alfred_Sisley_1.jpg': 'Alfred_Sisley_1.jpg', './dataset/train_images/Amedeo_Modigliani/Amedeo_Modigliani_1.jpg': 'Amedeo_Modigliani_1.jpg'}
